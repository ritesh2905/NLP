# %% [markdown]
# # NLP - 01

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
def lex_div(text):
    return len(text)/len(set(text))

# %%
def percentage(count, total):
    return 100*count/total

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']

# %%
len(sent1)
# Out:
# 4

# %%
lex_div(sent1)
# Out:
# 1.0

# %%
percentage(sent1.count('me'),len(sent1))
# Out:
# 25.0

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
ex1 = ['Ritz','is', 'learning', 'nlp', 'using', 'nltk']

# %%
sorted(ex1)
# Out:
# ['Ritz', 'is', 'learning', 'nlp', 'nltk', 'using']

# %%
ex1.count('n')
# Out:
# 0

# %%
['I','am']+['learning','nlp']
# Out:
# ['I', 'am', 'learning', 'nlp']

# %%
sent4 + sent1
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':',
#  'Call',
#  'me',
#  'Ishmael',
#  '.']

# %%
sent1.append("Maybe")

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Maybe']

# %%
text4[11111]
# Out:
# 'rights'

# %%
text4.index('rights')
# Out:
# 1219

# %%
text5[123:132]
# Out:
# ['boo', '.', 'JOIN', 'PART', 'he', 'drew', 'a', 'girl', 'with']

# %%
text6[1500:1525]
# Out:
# ['dictatorship',
#  '.',
#  'A',
#  'self',
#  '-',
#  'perpetuating',
#  'autocracy',
#  'in',
#  'which',
#  'the',
#  'working',
#  'classes',
#  '--',
#  'WOMAN',
#  ':',
#  'Oh',
#  ',',
#  'there',
#  'you',
#  'go',
#  ',',
#  'bringing',
#  'class',
#  'into',
#  'it']

# %%
sent = ['1st','2nd','3rd','4th','5th','6th','7th','8th','9th','10th']

# %%
sent[4]
# Out:
# '5th'

# %%
sent[6]
# Out:
# '7th'

# %%
sent[3:5]
# Out:
# ['4th', '5th']

# %%
sent[0] = 'first'
sent[9] = 'last'

# %%
len(sent)
# Out:
# 10

# %%
sent[1:9] = ['second', 'third']

# %%
sent
# Out:
# ['first', 'second', 'third', 'last']

# %%
sent[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-9d73df3f8677> in <module>()
# ----> 1 sent[9]
#
# IndexError: list index out of range

# %%
vocab = set(text1)
vocab_size = len(vocab)
vocab_size
# Out:
# 19317

# %%
name = 'Ritesh'
name[3]
# Out:
# 'e'

# %%
name[:5]
# Out:
# 'Rites'

# %%
name*2
# Out:
# 'RiteshRitesh'

# %%
name + 'K'
# Out:
# 'RiteshK'

# %%
' '.join(['Ritesh', 'Kumar'])
# Out:
# 'Ritesh Kumar'

# %%
'Ritesh Kumar'.split()
# Out:
# ['Ritesh', 'Kumar']

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done','more', 'is', 'said', 'than', 'done']

# %%
tokens = set(saying)

# %%
tokens = sorted(tokens)

# %%
tokens[-4:]
# Out:
# ['is', 'more', 'said', 'than']

# %%
fd = FreqDist(text1)

# %%
fd
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
fd.most_common()
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624),
#  ('The', 612),
#  ('their', 612),
#  ('are', 586),
#  ('they', 586),
#  ('an', 582),
#  ('some', 578),
#  ('then', 571),
# ...

# %%
fd['whale']
# Out:
# 906

# %%
fd.plot(50, cumulative=True )

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %%
v= set(text1)

# %%
long_words = [w for w in v if len(w)>15]

# %%
sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
medium_words = [w for w in v if len(w)>9 and len(w)<15]

# %%
sorted(medium_words)
# Out:
# ['ADDITIONAL',
#  'ADVENTURES',
#  'AFFGHANISTAN',
#  'APPLICATION',
#  'APPROACHING',
#  'Abominable',
#  'Accordingly',
#  'Advancement',
#  'Adventures',
#  'Affrighted',
#  'Afterwards',
#  'Aldrovandi',
#  'Aldrovandus',
#  'Alexanders',
#  'Alleghanian',
#  'Alleghanies',
#  'Ambergriese',
#  'Anacharsis',
#  'Archbishop',
#  'Archipelagoes',
#  'Arsacidean',
#  'Asphaltites',
#  'Australian',
#  'BLACKSMITH',
#  'BLACKSTONE',
#  'BREAKWATER',
#  'Babylonian',
#  'Bartholomew',
#  'Basilosaurus',
#  'Belisarius',
#  'Belshazzar',
#  'Biographical',
#  'Blacksmith',
#  'Blackstone',
#  'Blocksburg',
#  'Bonapartes',
#  'Bonneterre',
#  'Brighggians',
#  'Bulkington',
#  'CHRONICLER',
#  'COMMERCIAL',
#  'CONVERSATIONS',
#  'Californian',
#  'Canterbury',
#  'Capricornus',
#  'Champollion',
#  'Charlemagne',
#  'Chartering',
#  'Christendom',
#  'Christianity',
#  'Christians',
#  'Circassian',
#  'Circumambulate',
#  'Commanders',
#  'Commodores',
#  'Commonwealth',
# ...

# %%
v2 = set(text4)
long_words2 = [w for w in v2 if len(w)>15]

# %%
sorted(long_words2)
# Out:
# ['RESPONSIBILITIES',
#  'antiphilosophists',
#  'constitutionally',
#  'contradistinction',
#  'discountenancing',
#  'disqualification',
#  'enthusiastically',
#  'instrumentalities',
#  'internationality',
#  'irresponsibility',
#  'misappropriation',
#  'misrepresentation',
#  'misunderstanding',
#  'responsibilities',
#  'sentimentalizing',
#  'transcontinental',
#  'uncharitableness',
#  'unconstitutional']

# %%
v3 = set(text5)
long_words3 = [w for w in v3 if len(w)>15]
sorted(long_words3)
# Out:
# ['!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '#talkcity_adults',
#  '(((((((((((((((((',
#  '((((((((((((((((((',
#  '((((((((((((((((((((',
#  '(((((((((((((((((((((',
#  '(((((((((((((((((((((((',
#  '((((((((((((((((((((((((',
#  '(((((((((((((((((((((((((',
#  '((((((((((((((((((((((((((',
#  ')))))))))))))))))',
#  ')))))))))))))))))))',
#  ')))))))))))))))))))))',
#  '))))))))))))))))))))))',
#  '))))))))))))))))))))))))))))',
#  ')))))))))))))))))))))))))))))))',
#  '--------------------',
#  '.(..(.vMp3 v1.7.4.).)',
#  '.(..(.vMp3 vi.p.t.)..).',
#  '................',
#  '..................',
#  '...................',
#  '....................',
#  '........................',
#  '..............................',
#  '.A.n.a.c.?.n.?.a.',
#  '//www.wunderground.com/cgi-bin/findweather/getForecast?query=95953#FIR',
# ...

# %%
fd = FreqDist(text5)
sorted([w for w in set(text5) if len(w)>7 and fd[w]>7])
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
list(bigrams(['more', 'is', 'said', 'than', 'done']))
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
fd2 = FreqDist([len(w) for w in text1])

# %%
fd2
# Out:
# FreqDist({3: 50223, 1: 47933, 4: 42345, 2: 38513, 5: 26597, 6: 17111, 7: 14399, 8: 9966, 9: 6428, 10: 3528, ...})

# %%
fd2.keys()
# Out:
# dict_keys([1, 4, 2, 6, 8, 9, 11, 5, 7, 3, 10, 12, 13, 14, 16, 15, 17, 18, 20])

# %%
fd2.items()
# Out:
# dict_items([(1, 47933), (4, 42345), (2, 38513), (6, 17111), (8, 9966), (9, 6428), (11, 1873), (5, 26597), (7, 14399), (3, 50223), (10, 3528), (12, 1053), (13, 567), (14, 177), (16, 22), (15, 70), (17, 12), (18, 1), (20, 1)])

# %%
fd2.max()
# Out:
# 3

# %%
fd2.freq(3)
# Out:
# 0.19255882431878046

# %%
sorted([w for w in set(text1) if w.endswith('ness')])
# Out:
# ['Business',
#  'Darkness',
#  'Loveliness',
#  'Madness',
#  'Righteousness',
#  'Unfitness',
#  'Whiteness',
#  'Witness',
#  'aboriginalness',
#  'acridness',
#  'acuteness',
#  'adhesiveness',
#  'apprehensiveness',
#  'artificialness',
#  'awfulness',
#  'awkwardness',
#  'bashfulness',
#  'bigness',
#  'bitterness',
#  'blackness',
#  'blandness',
#  'blankness',
#  'bleakness',
#  'blueness',
#  'boldness',
#  'brawniness',
#  'breezelessness',
#  'brightness',
#  'brigness',
#  'business',
#  'calmness',
#  'carelessness',
#  'cautiousness',
#  'cheerfulness',
#  'childlessness',
#  'clearness',
#  'closeness',
#  'collectedness',
#  'comfortableness',
#  'compactness',
#  'comprehensiveness',
#  'consciousness',
#  'coolness',
#  'courageousness',
#  'craziness',
#  'creativeness',
#  'crookedness',
#  'curiousness',
#  'daintiness',
#  'dampness',
#  'darkness',
#  'dauntlessness',
#  'deadliness',
#  'deceitfulness',
#  'deliciousness',
#  'desolateness',
# ...

# %%
sorted([t for t in set(text4) if 'gnt' in t ])
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
sorted([k for k in set(text2) if k.istitle()])
# Out:
# ['7000L',
#  'A',
#  'Abbeyland',
#  'About',
#  'Absence',
#  'Abundance',
#  'Add',
#  'Affecting',
#  'After',
#  'Again',
#  'Against',
#  'Ah',
#  'All',
#  'Allenham',
#  'Allow',
#  'Almost',
#  'Altogether',
#  'Am',
#  'Among',
#  'Amongst',
#  'An',
#  'And',
#  'Annamaria',
#  'Anne',
#  'Another',
#  'Anxiety',
#  'April',
#  'Are',
#  'As',
#  'Ashamed',
#  'Astonished',
#  'Astonishment',
#  'At',
#  'Austen',
#  'Avignon',
#  'Ay',
#  'Aye',
#  'Bad',
#  'Bartlett',
#  'Barton',
#  'Bath',
#  'Beautifully',
#  'Because',
#  'Before',
#  'Being',
#  'Believe',
#  'Benevolent',
#  'Berkeley',
#  'Besides',
#  'Betty',
#  'Between',
#  'Beyond',
#  'Biddy',
#  'Bishop',
#  'Bond',
#  'Bonomi',
#  'Born',
#  'Brandon',
#  'Bristol',
#  'Brown',
#  'Building',
#  'Buildings',
#  'Burgess',
#  'Business',
#  'But',
#  'By',
#  'Can',
#  'Careless',
#  'Careys',
#  'Cartwright',
#  'Casino',
#  'Cassino',
#  'Certainly',
#  'Chagrined',
#  'Charlotte',
#  'Choice',
# ...

# %%
sorted([a for a in set(sent7) if a.isdigit()])
# Out:
# ['29', '61']

# %%
sorted([w for w in set(text7) if '-' and 'index' in w])
# Out:
# ['Stock-index',
#  'index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'indexers',
#  'indexes',
#  'stock-index']

# %%
sorted([w for w in set(text3) if w.istitle() and len(w)>10])
# Out:
# ['Abelmizraim',
#  'Allonbachuth',
#  'Beerlahairoi',
#  'Canaanitish',
#  'Chedorlaomer',
#  'Girgashites',
#  'Hazarmaveth',
#  'Hazezontamar',
#  'Ishmeelites',
#  'Jegarsahadutha',
#  'Jehovahjireh',
#  'Kirjatharba',
#  'Melchizedek',
#  'Mesopotamia',
#  'Peradventure',
#  'Philistines',
#  'Zaphnathpaaneah']

# %%
sorted([w for w in set(sent7) if not w.islower()])
# Out:
# [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']

# %%
sorted([w for w in set(text2) if 'cie' in w or 'cei' in w])
# Out:
# ['ancient',
#  'ceiling',
#  'conceit',
#  'conceited',
#  'conceive',
#  'conscience',
#  'conscientious',
#  'conscientiously',
#  'deceitful',
#  'deceive',
#  'deceived',
#  'deceiving',
#  'deficiencies',
#  'deficiency',
#  'deficient',
#  'delicacies',
#  'excellencies',
#  'fancied',
#  'insufficiency',
#  'insufficient',
#  'legacies',
#  'perceive',
#  'perceived',
#  'perceiving',
#  'prescience',
#  'prophecies',
#  'receipt',
#  'receive',
#  'received',
#  'receiving',
#  'society',
#  'species',
#  'sufficient',
#  'sufficiently',
#  'undeceive',
#  'undeceiving']

# %%
# total words in Moby Dick
len(text1)
# Out:
# 260819

# %%
# total words set in Moby Dick
len(set(text1))
# Out:
# 19317

# %%
# total distinct word in Moby Dick
len(set([w.lower() for w in text1]))
# Out:
# 17231

# %%
# elimination of punctuation in above 
len(set([w.lower() for w in text1 if w.isalpha()]))
# Out:
# 16948
